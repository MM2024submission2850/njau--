# %%
def writetoken2txt(questionlist, path):
    tokenlist = []
    for each in questionlist:
        # print(each)
        eachlist = list(each)
        print(eachlist)
        count = 0
        for i in range(len(eachlist)):
            i = count
            if i < len(eachlist):
                if eachlist[i] == "【":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Food" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "】":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Food" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Food", "S-Food", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Food", "E-Food", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "{":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Made" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "}":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Made" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Made", "S-Made", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Made", "E-Made", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "[":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Contain" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "]":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Contain" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Contain", "S-Contain", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Contain", "E-Contain", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "^":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Over" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "^":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Over" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Over", "S-Over", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Over", "E-Over", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "%":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Fake" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "%":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Fake" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Fake", "S-Fake", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Fake", "E-Fake", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "(":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Below" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != ")":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Below" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Below", "S-Below", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Below", "E-Below", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "*":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Happen" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "*":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Happen" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Happen", "S-Happen", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Happen", "E-Happen", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "$":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Produce" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "$":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Produce" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Produce", "S-Produce", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Produce", "E-Produce", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "@":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Sale" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "@":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Sale" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Sale", "S-Sale", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Sale", "E-Sale", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "#":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Time" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "#":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Time" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Time", "S-Time", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Time", "E-Time", 1)
                                count = i+2+j+1
                                break
                elif eachlist[i] == "&":
                    eachlist[i+1] = eachlist[i+1] + "\t" + "B-Person" + "\n"
                    tokenlist.append(eachlist[i+1])
                    for j in range(len(eachlist[i+2:])):
                        if j < len(eachlist[i+2:]):
                            if eachlist[i+2+j] != "&":
                                eachlist[i+2+j] = eachlist[i+2+j] + "\t" + "I-Person" + "\n"
                                tokenlist.append(eachlist[i+2+j])
                            else:
                                if j == 0:
                                    tokenlist[-1] = tokenlist[-1].replace("B-Person", "S-Person", 1)
                                else:
                                    tokenlist[-1] = tokenlist[-1].replace("I-Person", "E-Person", 1)
                                count = i+2+j+1
                                break
                else:
                    eachlist[i] = eachlist[i] + "\t" + "O" + "\n"
                    tokenlist.append(eachlist[i])
                    count = count + 1
        tokenlist.append("\n")
    for token in tqdm(tokenlist):
        baseio.writetxt_a(token, path)

# %%
for i in fileArray:
    result=read_and_divide(result,i)
random.shuffle(result)
print(result)
num=int(len(result)*0.1)
text_txt=result[0:num]
train_txt=result[num:]
output("train.txt",train_txt)
output("text.txt",text_txt)
