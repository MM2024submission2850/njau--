# %%
from lxml import etree
import json
import requests
import pandas as pd
title=[]
type1=[]
unit=[]
content=[]
protect_unit=[]
rx_time=[]
for i in range(3):
    print('爬取第{}页'.format(i))
    recommed_url='http://www.ihchina.cn/Article/Index/getProject.html?province=&rx_time=&type=&cate=&keywords=&category_id=16&limit=10&p={0}'.format(i)
    print(recommed_url)
    res=requests.get(url=recommed_url).content.decode('utf-8','ignore')
    diss_dict=json.loads(res)
    print(diss_dict)
    for i in diss_dict['list']:
        print(i)
        title.append(i['title'])#名称
        type1.append(i['type'])#类型
        unit.append(i['unit'])#申报地区或单位
        protect_unit.append(i['protect_unit'])#保护单位
        content.append(i['content'])#内容
        rx_time.append(i['rx_time'])#时间
data={
    '名称':title,
    '类型':type1,
    '申报地区或单位':unit,
    '保护单位':protect_unit,
    '内容':content,
    '时间':rx_time
}
df=pd.DataFrame(data)
df.to_excel('国家非文化遗产1.xlsx',encoding='utf-8')
# Out:
# 爬取第0页
# http://www.ihchina.cn/Article/Index/getProject.html?province=&rx_time=&type=&cate=&keywords=&category_id=16&limit=10&p=0
# ...

# %%
from lxml import etree
import json
import requests
import pandas as pd
headers = {
    'Accept': 'application/json, text/plain, */*',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    'Connection': 'keep-alive',
    'Content-Length': '0',
    'Content-Type': 'application/x-www-form-urlencoded',
    'Host': '49.72.51.110:9018',
    'Origin': 'http://jsfybh.com',
    'Referer': 'http://jsfybh.com/',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36'
  }
title=[]
type1=[]
unit=[]
content=[]
protect_unit=[]
rx_time=[]
pici=[]
quanwen=[]
province=[]

for i in range(251,252):
    print('爬取第{}页'.format(i))
    data = {}
    data = json.dumps(data)
    recommed_url='http://49.72.51.110:9018/directory/searchListDirectory?page={0}'.format(i)+'&rows=12&type=1&searchMap=%7B%22city%22%3A%22%22%2C%22district%22%3A%22%22%2C%22batch_id%22%3A%22%22%2C%22category_id%22%3A%22%22%2C%22level_id%22%3A%22%22%2C%22key_world%22%3A%22%22%2C%22status%22%3A1%7D'

    print(recommed_url)
    res=requests.post(url=recommed_url,data=data,headers=headers).content.decode('utf-8','ignore')
    diss_dict=json.loads(res)
    #print(res)
    print(diss_dict)
    for i in diss_dict['object']['rows']:
        title.append(i['directory_name'])#名称
        type1.append(i['category_name'])#类型
        province.append(i['proname'])
        unit.append(i['cityname'])#申报地区或单位
        protect_unit.append(i['level_name'])#保护单位
        pici.append(i["batch_name"])#批次
        quanwen.append(i["directory_body_text"])
data={
    '名称':title,
    '类型':type1,
    '申报省份':province,
    '申报城市':unit,
    '保护单位':protect_unit,
    '批次':pici,
    '全文':quanwen,
}
df=pd.DataFrame(data)
df.to_excel('江苏非文化遗产1.xlsx',encoding='utf-8')
# Out:
# 爬取第251页
# http://49.72.51.110:9018/directory/searchListDirectory?page=251&rows=12&type=1&searchMap=%7B%22city%22%3A%22%22%2C%22district%22%3A%22%22%2C%22batch_id%22%3A%22%22%2C%22category_id%22%3A%22%22%2C%22level_id%22%3A%22%22%2C%22key_world%22%3A%22%22%2C%22status%22%3A1%7D
# ...

# %%
df=pd.DataFrame(data)
df.to_excel('江苏非文化遗产1.xlsx',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e6c4fb9c0c4d> in <module>
# ----> 1 df=pd.DataFrame(data)
#       2 df.to_excel('江苏非文化遗产1.xlsx',encoding='utf-8')
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     588         else:
#     589             if index is None or columns is None:
# --> 590                 raise ValueError("DataFrame constructor not properly called!")
#     591
#     592             if not dtype:
#
# ValueError: DataFrame constructor not properly called!
